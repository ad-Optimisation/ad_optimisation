# %% [markdown]
# import packages

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# load a sample image

# %%
# import the necessary packages
import argparse
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

sampleImage5 = '/home/Challenge_Data/Assets/adunit-cartier-clash-swipe-or-tap-to-scroll-ch-mpu/landing_2.png'

image = cv2.imread(sampleImage5)
(h, w, c) = image.shape[:3]

# display the image width, height, and number of channels to our
# terminal
print("width: {} pixels".format(w))
print("height: {}  pixels".format(h))
print("channels: {}".format(c))

img = mpimg.imread(sampleImage5)
imgplot = plt.imshow(img)
plt.show()
# Out:
# width: 600 pixels
# height: 500  pixels
# channels: 3

# %% [markdown]
# analyze image

# %%
result = DeepFace.analyze(sampleImage5, actions =['emotion'])
